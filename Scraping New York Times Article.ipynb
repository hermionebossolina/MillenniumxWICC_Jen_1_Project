# %%
#API Key: Q76q1FN7MaZPlUJaZZF6qJ4rFXO0tRd2

# %%
#created an API key and imported packages 

import requests as req
import time
API_KEY='Q76q1FN7MaZPlUJaZZF6qJ4rFXO0tRd2' # your API key
TOPIC='Technology' # keyword
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# %%
# Download Vader lexicon 
nltk.download('vader_lexicon')

# Initialize the sentiment analyzer
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/hermionebossolina/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
store_headlines = []

# %%
#made a list of all possible AI references that headlines can use
ai_references = [
    "Artificial Intelligence",
    "AI",
    "A.I.",
    "M.L.",
    "Machine Intelligence",
    "Machine Learning",
    "ML",
    "Neural Networks",
    "Deep Learning",
    "DL",
    "Natural Language Processing",
    "NLP",
    "Robotics",
    "Automated Intelligence",
    "Intelligent Systems",
    "Cognitive Computing",
    "Expert Systems",
    "Autonomous Agents",
    "Sentient Machines",
    "Smart Machines"
]

# %% [markdown]
# ### 2020 Headlines

# %%
year = 2020

def func_head(TOPIC, API_KEY, year):
    store_headlines = []
    begin_date = f"{year}0101"
    end_date = f'{year}1231'
    url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={TOPIC}&api-key={API_KEY}&begin_date={begin_date}&end_date={end_date}'
    response = req.get(url).json()
    for doc in response['response']['docs']:
        store_headlines.append(doc['headline']['main'])
    time.sleep(12)
    return store_headlines

# %%
store_headlines_2020 = func_head(TOPIC, API_KEY, 2020)

# %%
store_headlines_2020
# Out:
# ['QAnon is still spreading on Facebook, despite a ban.',
#  'As China Tracked Muslims, Alibaba Showed Customers How They Could, Too',
#  'Watch SpaceX’s Starship Launch and Explode in Crash Landing',
#  'Uber Jettisons Flying Car Project',
#  'Uber, After Years of Trying, Is Handing Off Its Self-Driving Car Project',
#  'As Deadline Lapses, Trump Administration Continues TikTok Talks',
#  'Why Your Workplace Software Stinks',
#  'Marc Benioff Sets His Sights on Microsoft',
#  'Salesforce to Acquire Slack for $27.7 Billion',
#  'London A.I. Lab Claims Breakthrough That Could Accelerate Drug Discovery']

# %%
#for general headlines conduct sentiment analysis with polarity scores 

sentiments = []
for headline in store_headlines_2020:
    sentiment = sid.polarity_scores(headline)
    sentiments.append(sentiment)

# Print the sentiments
for headline, sentiment in zip(store_headlines, sentiments):
    print(f"Headline: {headline}")
    print(f"Sentiment: {sentiment}")
    print()
# Out:
# Headline: QAnon is still spreading on Facebook, despite a ban.
# Sentiment: {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.4449}
#
# Headline: As China Tracked Muslims, Alibaba Showed Customers How They Could, Too
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: Watch SpaceX’s Starship Launch and Explode in Crash Landing
# Sentiment: {'neg': 0.252, 'neu': 0.748, 'pos': 0.0, 'compound': -0.4019}
#
# Headline: Uber Jettisons Flying Car Project
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: Uber, After Years of Trying, Is Handing Off Its Self-Driving Car Project
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: As Deadline Lapses, Trump Administration Continues TikTok Talks
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: Why Your Workplace Software Stinks
# Sentiment: {'neg': 0.333, 'neu': 0.667, 'pos': 0.0, 'compound': -0.25}
#
# ...

# %%
# Extract compound sentiment scores from the sentiments list
compound_scores = [sentiment['compound'] for sentiment in sentiments]

# Plot a histogram of compound sentiment scores
plt.hist(compound_scores, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 2021 Headlines

# %%
store_headlines_2021 = func_head(TOPIC, API_KEY, 2021)

# %%
store_headlines_2021
# Out:
# ['The 2021 Good Tech Awards',
#  'Meta aims for ‘deep compatibility’ with blockchain, according to an internal post.',
#  'The New Get-Rich-Faster Job in Silicon Valley: Crypto Start-Ups',
#  'Europe Pushes New Rules Turning Gig Workers Into Employees',
#  'Congress gets a crash course on cryptocurrency.',
#  'Square, Jack Dorsey’s payments company, changes its name to Block.',
#  'Investors Snap Up Metaverse Real Estate in a Virtual Land Boom',
#  'For Rules in Technology, the Challenge is to Balance Code and Law',
#  'Uber Survived the Spying Scandal. Some Careers Didn’t.',
#  'Clearview AI does well in another round of facial recognition accuracy tests.']

# %%
#for general headlines conduct sentiment analysis with polarity scores 

sentiments = []
for headline in store_headlines_2021:
    sentiment = sid.polarity_scores(headline)
    sentiments.append(sentiment)

# Print the sentiments
for headline, sentiment in zip(store_headlines, sentiments):
    print(f"Headline: {headline}")
    print(f"Sentiment: {sentiment}")
    print()
# Out:
# Headline: QAnon is still spreading on Facebook, despite a ban.
# Sentiment: {'neg': 0.0, 'neu': 0.337, 'pos': 0.663, 'compound': 0.7096}
#
# Headline: As China Tracked Muslims, Alibaba Showed Customers How They Could, Too
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: Watch SpaceX’s Starship Launch and Explode in Crash Landing
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: Uber Jettisons Flying Car Project
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: Uber, After Years of Trying, Is Handing Off Its Self-Driving Car Project
# Sentiment: {'neg': 0.351, 'neu': 0.649, 'pos': 0.0, 'compound': -0.4019}
#
# Headline: As Deadline Lapses, Trump Administration Continues TikTok Talks
# Sentiment: {'neg': 0.244, 'neu': 0.756, 'pos': 0.0, 'compound': -0.4404}
#
# Headline: Why Your Workplace Software Stinks
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# ...

# %%
# Extract compound sentiment scores from the sentiments list
compound_scores = [sentiment['compound'] for sentiment in sentiments]

# Plot a histogram of compound sentiment scores
plt.hist(compound_scores, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 2022 Headlines

# %%
store_headlines_2022 = func_head(TOPIC, API_KEY, 2022)

# %%
store_headlines_2022
# Out:
# ['31 Hours Inside SpaceX Mission Control',
#  'ByteDance Inquiry Finds Employees Obtained User Data of 2 Journalists',
#  'A New Chat Bot Is a ‘Code Red’ for Google’s Search Business',
#  'Elon Musk Says He Will Resign as Twitter C.E.O. When He Finds Successor',
#  'Bans on TikTok Gain Momentum in Washington and States',
#  'Bankman-Fried’s Arrest, 2023 Predictions and Your Questions Answered',
#  'Why Some Scientists Choose China’s Space Station for Research',
#  'Successful End of NASA Moon Mission Shifts Attention to SpaceX',
#  'Can ChatGPT Make This Podcast?',
#  'Indiana Sues TikTok for Security and Child Safety Violations']

# %%
#for general headlines conduct sentiment analysis with polarity scores 

sentiments = []
for headline in store_headlines_2022:
    sentiment = sid.polarity_scores(headline)
    sentiments.append(sentiment)

# Print the sentiments
for headline, sentiment in zip(store_headlines, sentiments):
    print(f"Headline: {headline}")
    print(f"Sentiment: {sentiment}")
    print()
# Out:
# Headline: QAnon is still spreading on Facebook, despite a ban.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: As China Tracked Muslims, Alibaba Showed Customers How They Could, Too
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: Watch SpaceX’s Starship Launch and Explode in Crash Landing
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: Uber Jettisons Flying Car Project
# Sentiment: {'neg': 0.157, 'neu': 0.719, 'pos': 0.124, 'compound': -0.128}
#
# Headline: Uber, After Years of Trying, Is Handing Off Its Self-Driving Car Project
# Sentiment: {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'compound': 0.5267}
#
# Headline: As Deadline Lapses, Trump Administration Continues TikTok Talks
# Sentiment: {'neg': 0.255, 'neu': 0.745, 'pos': 0.0, 'compound': -0.34}
#
# Headline: Why Your Workplace Software Stinks
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# ...

# %%
# Extract compound sentiment scores from the sentiments list
compound_scores = [sentiment['compound'] for sentiment in sentiments]

# Plot a histogram of compound sentiment scores
plt.hist(compound_scores, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 2023 Headlines

# %%
store_headlines_2023 = func_head(TOPIC, API_KEY, 2023)

# %%
store_headlines_2023
# Out:
# ['The 2023 Good Tech Awards',
#  'Our 2024 Predictions, and Jenny Slate Answers Your Hard Questions',
#  '8 Stunning New Images From Neuroscience',
#  'Google’s Epic Loss, Silicon Valley’s Curious New Subculture and How 2023 Changed the Internet',
#  'Political Debate Is Rife on TikTok. Politicians? Not So Much.',
#  'Judge Upholds Texas TikTok Ban on Government Devices',
#  'Google’s Next Top Model, Will the Cybertruck Crash? and This Week in A.I.',
#  'Five Ways A.I. Could Be Regulated',
#  'Google Updates Bard Chatbot With ‘Gemini’ A.I. as It Chases ChatGPT',
#  'NASA’s Moon Race Is Running Late']

# %%
#for general headlines conduct sentiment analysis with polarity scores 

sentiments = []
for headline in store_headlines_2023:
    sentiment = sid.polarity_scores(headline)
    sentiments.append(sentiment)

# Print the sentiments
for headline, sentiment in zip(store_headlines, sentiments):
    print(f"Headline: {headline}")
    print(f"Sentiment: {sentiment}")
    print()
# Out:
# Headline: QAnon is still spreading on Facebook, despite a ban.
# Sentiment: {'neg': 0.0, 'neu': 0.337, 'pos': 0.663, 'compound': 0.7096}
#
# Headline: As China Tracked Muslims, Alibaba Showed Customers How They Could, Too
# Sentiment: {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'compound': -0.1027}
#
# Headline: Watch SpaceX’s Starship Launch and Explode in Crash Landing
# Sentiment: {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.3818}
#
# Headline: Uber Jettisons Flying Car Project
# Sentiment: {'neg': 0.139, 'neu': 0.723, 'pos': 0.139, 'compound': 0.0}
#
# Headline: Uber, After Years of Trying, Is Handing Off Its Self-Driving Car Project
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: As Deadline Lapses, Trump Administration Continues TikTok Talks
# Sentiment: {'neg': 0.34, 'neu': 0.66, 'pos': 0.0, 'compound': -0.5574}
#
# Headline: Why Your Workplace Software Stinks
# Sentiment: {'neg': 0.174, 'neu': 0.71, 'pos': 0.116, 'compound': -0.2263}
#
# ...

# %%
# Extract compound sentiment scores from the sentiments list
compound_scores = [sentiment['compound'] for sentiment in sentiments]

# Plot a histogram of compound sentiment scores
plt.hist(compound_scores, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#went through everything in range from 2020-2023

for year in range(2020, 2024):
#scraped for 120 pages from the beggining of the year (begin date jan 1st) to the end of the year (end date Dec 31st)
    for i in range(120):
        begin_date = f"{year}0101" 
        end_date = f'{year}1231'
        url='https://api.nytimes.com/svc/search/v2/articlesearch.json?q='+TOPIC+'&api-key='+API_KEY+'&page='+str(i)
        response = req.get(url).json()
        #made sure to sleep every 6 seconds 
        time.sleep(6)
        try:
          #print(response['response']['docs'][1]['headline']['main'])
          #store_headlines.append(response['response']['docs'][1]['headline']['main'])
            for doc in response['response']['docs']:
                store_headlines.append(doc['headline']['main'])
        #except:
         #print()   
        except KeyError:
            pass
print(store_headlines)

# %%
import requests as req
import time

store_headlines = []

for year in range(2020, 2024):
    for i in range(1):
        begin_date = f"{year}0101"
        end_date = f'{year}1231'
        url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Technology&api-key=Q76q1FN7MaZPlUJaZZF6qJ4rFXO0tRd2&page={i}&begin_date={begin_date}&end_date={end_date}'
        response = req.get(url).json()
        time.sleep(6)
        try:
            for doc in response['response']['docs']:
                store_headlines.append(doc['headline']['main'])
        except KeyError as e:
            print(f"KeyError occurred: {e}")
            # Handle the exception appropriately if needed
            pass

print(store_headlines)

# %%
url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=' + TOPIC + '&api-key=' + API_KEY
query = req.get(url)
data = query.json()

# %%
def nytimes_query(
    
    api_key, query,
    glocations = None, headline = None, news_desk = None,
    organizations = None, persons = None, byline = None,
    subject = None, news_type = None, type_of_material = None,
    begin_date = None, end_date = None, n_page = 0
    ):
# Set the base url for the query
base_url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={query}'

# Empty dictionary for filters
filter_queries = {}
# empty dictionary for dates
dates = {}
# Populate the filter dictionary
if glocations:
    filter_queries.update({'glocations': glocations})
if headline:
    filter_queries.update({'headline': headline})
if news_desk:
    filter_queries.update({'news_desk': news_desk})
if organizations:
    filter_queries.update({'organizations': organizations})
if persons:
    filter_queries.update({'persons': persons})
if subject:
    filter_queries.update({'subject': subject})
if byline:
    filter_queries.update({'byline': byline})
if news_type:
    filter_queries.update({'news_type': news_type})
if type_of_material:
    filter_queries.update({'type_of_material': type_of_material})
# Populate the date dictionary
if begin_date:
    dates.update({'begin_date': begin_date})
if end_date:
    dates.update({'end_date':end_date})
# If 1 filter is present, and/or date params, add to URL and execute query
if len(filter_queries) == 1:
    base_url += f'&fq={list(filter_queries.keys())[0]}:     ({list(filter_queries.values())[0]})'
if len(dates) == 1:
    base_url += f'&{list(filter_queries.keys())[0]}={list(filter_queries.values())[0]}&'
elif len(dates) == 2:
    base_url += '&'
for i in dates.keys():
    base_url += f'{i}={dates[i]}&'
# If 2 or more filters are present, concatenate with AND, add dates if present and execute
elif  len(filter_queries) > 1:
    base_url += '&fq='
    for i in filter_queries.keys():
       base_url += f'{i}:({filter_queries[i]}) AND '
    # remove the last 'AND ' at the end of the loop
    base_url = base_url[:-5]
if len(dates) == 1:
    base_url += f'&{list(filter_queries.keys())[0]}={list(filter_queries.values())[0]}&'
elif len(dates) == 2:
    base_url += '&'
for i in dates.keys():
    base_url += f'{i}={dates[i]}&'
# concatenate page number and api key and make the request.
# Returns a truncated JSON indexed past the metadata
# If you want the full json, simply remove ['response']['docs']
# from the return line
base_url += f'&page={n_page}'
base_url += f'&api-key={api_key}'
r = requests.get(base_url)
json_data = r.json()
return r.json()['response']['docs']
# Out:
#   Cell In[7], line 10
#     base_url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=' + {query}
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def review_url_names(api_key, query, n_pages_min, n_pages_max, **kwargs):
# empty lists for URLs and restaurant names
urls = []
names = []
# Iterate through the specified number of pages (min and max
# to allow multiple subqueries to build a dataset)
for i in range(n_pages_min, n_pages_max):
# Run the query helper function, it inherits kwargs from the main 
# function
    qref = nytimes_query(api_key, query, n_page = i, **kwargs)
    # Strip the url to include the restaurant name and add to list
    names += [j['web_url'].split('dining/')[1][:-5].replace('-', ' ').replace('reviews/', '') for j in qref]
    # Append urls to list
    urls += [k['web_url'] for k in qref]
    # Wait for 6 seconds before restarting the loop
    time.sleep(6)
# Both lists are returned
return urls, names

# %%
import requests as req
import time

store_headlines = []

for year in range(2020, 2020):
    for i in range(1):
        begin_date = f"{year}0101"
        end_date = f'{year}1231'
        url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Technology&api-key=Q76q1FN7MaZPlUJaZZF6qJ4rFXO0tRd2&page={i}&begin_date={begin_date}&end_date={end_date}'
        response = req.get(url).json()
        time.sleep(6)
        try:
            for doc in response['response']['docs']:
                store_headlines.append(doc['headline']['main'])
        except KeyError as e:
            print(f"KeyError occurred: {e}")
            # Handle the exception appropriately if needed
            pass

print(store_headlines)
# Out:
# []

# %%
store_headlines
# Out:
# []

# %%
#response['response']['docs']
# Out:
# [{'abstract': 'Mustafa Suleyman is leaving a start-up called Inflection to take the senior position with Microsoft.',
#   'web_url': 'https://www.nytimes.com/2024/03/19/technology/mustafa-suleyman-google-gemini.html',
#   'snippet': 'Mustafa Suleyman is leaving a start-up called Inflection to take the senior position with Microsoft.',
#   'lead_paragraph': 'Mustafa Suleyman, a co-founder of Google’s DeepMind artificial intelligence lab, is leaving the start-up he was running to lead Microsoft’s consumer A.I. business, in another sign of Microsoft’s aggressive plans for the technology.',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2024/03/19/multimedia/19MICROSOFT-AI-gpqw/19MICROSOFT-AI-gpqw-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
# ...

# %%
fq=pub_year:(2020)
# Out:
#   File "/var/folders/yn/3n1g6x553tb8q2xt8dkll0cr0000gn/T/ipykernel_31529/1159250659.py", line 1
#     fq=pub_year:(2020)
#                ^
# SyntaxError: invalid syntax

# %%
#response['response']['docs'][1].values()
# Out:
# dict_values(['Local lawmakers in the Minnesota city voted on Thursday to guarantee a minimum hourly wage to ride-hailing drivers.', 'https://www.nytimes.com/2024/03/15/technology/uber-lyft-minneapolis-minimum-wage.html', 'Local lawmakers in the Minnesota city voted on Thursday to guarantee a minimum hourly wage to ride-hailing drivers.', 'Uber and Lyft are threatening to pull out of Minneapolis after a City Council vote there guaranteed a minimum hourly wage to drivers.', 'The New York Times', [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2024/03/15/multimedia/15UBER-bzwl/15UBER-bzwl-articleLarge.jpg', 'height': 400, 'width': 600, 'legacy': {'xlarge': 'images/2024/03/15/multimedia/15UBER-bzwl/15UBER-bzwl-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 400}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'popup', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2024/03/15/multimedia/
# ...

# %%
response['response']['docs'][1].keys()
# Out:
# dict_keys(['abstract', 'web_url', 'snippet', 'lead_paragraph', 'source', 'multimedia', 'headline', 'keywords', 'pub_date', 'document_type', 'news_desk', 'section_name', 'byline', 'type_of_material', '_id', 'word_count', 'uri'])

# %%
response['response']['docs'][1]['headline']['main']
# Out:
# 'Uber and Lyft Threaten to Pull Out of Minneapolis After City Council Vote'

# %%
#created new empty list for headlines 
store_headlines = []

#went through years 2020-2023
for year in range(2020, 2023):
    #went through pages 0 -400 and started at begin date (jan 1st) and end date (Dec 31st) for each year
    for i in range(0, 400):
        begin_date = f"{year}0101" 
        end_date = f'{year}1231'
        #use this URL to scrape the specific API key 
        url='https://api.nytimes.com/svc/search/v2/articlesearch.json?q='+'Technology'+'&api-key='+'Q76q1FN7MaZPlUJaZZF6qJ4rFXO0tRd2'+'&page='+str(i)
        response = req.get(url).json()
        #sleep every 6 seconds so that NYT don't think we are trying to hack them 
        time.sleep(6)
    try:
          #print(response['response']['docs'][1]['headline']['main'])
          #store_headlines.append(response['response']['docs'][1]['headline']['main'])
        
        #store the responses 
        for doc in response['response']['docs']:
            store_headlines.append(doc['headline']['main'])
        #except:
         #print()   
    except KeyError:
        pass
print(store_headlines)

# %%
#for general headlines conduct sentiment analysis with polarity scores 

sentiments = []
for headline in store_headlines:
    sentiment = sid.polarity_scores(headline)
    sentiments.append(sentiment)

# Print the sentiments
for headline, sentiment in zip(store_headlines, sentiments):
    print(f"Headline: {headline}")
    print(f"Sentiment: {sentiment}")
    print()
# Out:
# Headline: Is A.I. Already Taking Jobs? +A Filmmaker Tries Sora + The XZ Backdoor Caper
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: Want to Invest in SpaceX or Stripe? There’s a Fund for That.
# Sentiment: {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.0772}
#
# Headline: TikTok Turns to Nuns, Veterans and Ranchers in Marketing Blitz
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: 4 Things You Need to Know About Health Care Cyberattacks
# Sentiment: {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.4939}
#
# Headline: A.I.’s Messy Moment + Listeners Respond to Jonathan Haidt + Shrimp Jesus
# Sentiment: {'neg': 0.217, 'neu': 0.783, 'pos': 0.0, 'compound': -0.3612}
#
# Headline: A.I. Leaders Press Advantage With Congress as China Tensions Rise
# Sentiment: {'neg': 0.213, 'neu': 0.63, 'pos': 0.157, 'compound': -0.1779}
#
# Headline: The U.S. Investors Caught in the Scrum Over TikTok
# ...

# %%
# Extract compound sentiment scores from the sentiments list
compound_scores = [sentiment['compound'] for sentiment in sentiments]

# Plot a histogram of compound sentiment scores
plt.hist(compound_scores, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
ai_headlines = [headline for headline in store_headlines if any(word in headline for word in ai_references)]

# Analyze sentiment for each AI-related headline
ai_sentiments = []
for headline in ai_headlines:
    sentiment = sid.polarity_scores(headline)
    ai_sentiments.append(sentiment)

# Print the sentiments for AI-related headlines
for headline, sentiment in zip(ai_headlines, ai_sentiments):
    print(f"Headline: {headline}")
    print(f"Sentiment: {sentiment}")
    print()
# Out:
# Headline: Is A.I. Already Taking Jobs? +A Filmmaker Tries Sora + The XZ Backdoor Caper
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: A.I.’s Messy Moment + Listeners Respond to Jonathan Haidt + Shrimp Jesus
# Sentiment: {'neg': 0.217, 'neu': 0.783, 'pos': 0.0, 'compound': -0.3612}
#
# Headline: A.I. Leaders Press Advantage With Congress as China Tensions Rise
# Sentiment: {'neg': 0.213, 'neu': 0.63, 'pos': 0.157, 'compound': -0.1779}
#
# Headline: Microsoft Hires DeepMind Co-Founder to Run Consumer A.I.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Headline: Musk vs. OpenAI, Europe’s Tech Crackdown and a Month With the Vision Pro
# Sentiment: {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'compound': 0.25}
#
# Headline: China’s Rush to Dominate A.I. Comes With a Twist: It Depends on U.S. Technology
# Sentiment: {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'compound': -0.128}
#
# ...

# %%
compound_scores = [ai_sentiments['compound'] for ai_sentiments in ai_sentiments]

# Plot a histogram of compound sentiment scores
plt.hist(compound_scores, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#sentiment analysis for year 2020 only 
store_headlines = []
for year in range(2020):
    begin_date = f"{year}0101" 
    end_date = f'{year}1231'
    url='https://api.nytimes.com/svc/search/v2/articlesearch.json?q='+'Technology'+'&api-key='+'Q76q1FN7MaZPlUJaZZF6qJ4rFXO0tRd2'+'&page='+str(i)
    response = req.get(url).json()
    time.sleep(6)
    try:
          #print(response['response']['docs'][1]['headline']['main'])
          #store_headlines.append(response['response']['docs'][1]['headline']['main'])
        for doc in response['response']['docs']:
            store_headlines.append(doc['headline']['main'])
        #except:
         #print()   
    except KeyError:
        pass
print(store_headlines)



#running sentiment analysis on ai headlines 2020 
ai_headlines = [headline for headline in store_headlines if any(word in headline for word in ai_references)]

# Analyze sentiment for each AI-related headline
ai_sentiments_2020 = []
for headline in ai_headlines:
    sentiment = sid.polarity_scores(headline)
    ai_sentiments_2020.append(sentiment)

# Print the sentiments for AI-related headlines
for headline, sentiment in zip(ai_headlines, ai_sentiments_2020):
    print(f"Headline: {headline}")
    print(f"Sentiment: {sentiment}")
    print()
    
    
#creating graphs for AI headlines in 2020
compound_scores = [ai_sentiments_2020['compound'] for ai_sentiments_2020 in ai_sentiments_2020]

# Plot a histogram of compound sentiment scores
plt.hist(compound_scores, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#sentiment analysis for year 2021 only 
store_headlines = []
for year in range(2021):
    begin_date = f"{year}0101" 
    end_date = f'{year}1231'
    url='https://api.nytimes.com/svc/search/v2/articlesearch.json?q='+'Technology'+'&api-key='+'Q76q1FN7MaZPlUJaZZF6qJ4rFXO0tRd2'+'&page='+str(i)
    response = req.get(url).json()
    time.sleep(6)
    try:
          #print(response['response']['docs'][1]['headline']['main'])
          #store_headlines.append(response['response']['docs'][1]['headline']['main'])
        for doc in response['response']['docs']:
            store_headlines.append(doc['headline']['main'])
        #except:
         #print()   
    except KeyError:
        pass
print(store_headlines)



#running sentiment analysis on ai headlines 2020 
ai_headlines = [headline for headline in store_headlines if any(word in headline for word in ai_references)]

# Analyze sentiment for each AI-related headline
ai_sentiments_2021 = []
for headline in ai_headlines:
    sentiment = sid.polarity_scores(headline)
    ai_sentiments_2021.append(sentiment)

# Print the sentiments for AI-related headlines
for headline, sentiment in zip(ai_headlines, ai_sentiments_2021):
    print(f"Headline: {headline}")
    print(f"Sentiment: {sentiment}")
    print()
    
    
#creating graphs for AI headlines in 2020
compound_scores = [ai_sentiments_2021['compound'] for ai_sentiments_2021 in ai_sentiments_2021]

# Plot a histogram of compound sentiment scores
plt.hist(compound_scores, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#sentiment analysis for year 2022 only 
store_headlines = []
for year in range(2022):
    begin_date = f"{year}0101" 
    end_date = f'{year}1231'
    url='https://api.nytimes.com/svc/search/v2/articlesearch.json?q='+'Technology'+'&api-key='+'Q76q1FN7MaZPlUJaZZF6qJ4rFXO0tRd2'+'&page='+str(i)
    response = req.get(url).json()
    time.sleep(6)
    try:
          #print(response['response']['docs'][1]['headline']['main'])
          #store_headlines.append(response['response']['docs'][1]['headline']['main'])
        for doc in response['response']['docs']:
            store_headlines.append(doc['headline']['main'])
        #except:
         #print()   
    except KeyError:
        pass
print(store_headlines)



#running sentiment analysis on ai headlines 2022
ai_headlines = [headline for headline in store_headlines if any(word in headline for word in ai_references)]

# Analyze sentiment for each AI-related headline
ai_sentiments_2022 = []
for headline in ai_headlines:
    sentiment = sid.polarity_scores(headline)
    ai_sentiments_2022.append(sentiment)

# Print the sentiments for AI-related headlines
for headline, sentiment in zip(ai_headlines, ai_sentiments_2022):
    print(f"Headline: {headline}")
    print(f"Sentiment: {sentiment}")
    print()
    
    
#creating graphs for AI headlines in 2022
compound_scores = [ai_sentiments_2022['compound'] for ai_sentiments_2022 in ai_sentiments_2022]

# Plot a histogram of compound sentiment scores
plt.hist(compound_scores, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#sentiment analysis for year 2023 only 
store_headlines = []
for year in range(2023):
    begin_date = f"{year}0101" 
    end_date = f'{year}1231'
    url='https://api.nytimes.com/svc/search/v2/articlesearch.json?q='+'Technology'+'&api-key='+'Q76q1FN7MaZPlUJaZZF6qJ4rFXO0tRd2'+'&page='+str(i)
    response = req.get(url).json()
    time.sleep(6)
    try:
          #print(response['response']['docs'][1]['headline']['main'])
          #store_headlines.append(response['response']['docs'][1]['headline']['main'])
        for doc in response['response']['docs']:
            store_headlines.append(doc['headline']['main'])
        #except:
         #print()   
    except KeyError:
        pass
print(store_headlines)



#running sentiment analysis on ai headlines 2023
ai_headlines = [headline for headline in store_headlines if any(word in headline for word in ai_references)]

# Analyze sentiment for each AI-related headline
ai_sentiments_2023 = []
for headline in ai_headlines:
    sentiment = sid.polarity_scores(headline)
    ai_sentiments_2023.append(sentiment)

# Print the sentiments for AI-related headlines
for headline, sentiment in zip(ai_headlines, ai_sentiments_2023):
    print(f"Headline: {headline}")
    print(f"Sentiment: {sentiment}")
    print()
    
    
#creating graphs for AI headlines in 2023
compound_scores = [ai_sentiments_2023['compound'] for ai_sentiments_2023 in ai_sentiments_2023]

# Plot a histogram of compound sentiment scores
plt.hist(compound_scores, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
